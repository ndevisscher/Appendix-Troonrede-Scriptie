# %%
# %matplotlib inline
import pandas as pd
import re
from lxml import etree 
from bz2file import BZ2File
import bz2
import codecs
import xml
import glob
import os
import bs4
import collections
import itertools
import math
import networkx as nx
import community
import pickle
import numpy as np
from collections import defaultdict, Counter
from bs4 import BeautifulSoup
from pattern.nl import parsetree, pprint, singularize, pluralize
from pattern.metrics import readability
from xml import parsers
import xml.parsers.expat
from xml.etree import cElementTree as ET
from xml.dom.minidom import parse
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import timeit
import random

# %%
#Inladen van de noodzakelijke data om de grafieken te maken
yearFrame = pickle.load( open( "frame.txt", "rb" ) )
netwerkDict = pickle.load( open( "netwerkFull.p", "rb" ) )
tekst = pickle.load( open( "text.p", "rb" ) )
yearData = pickle.load( open("yeardata.p","rb"))

# %%
#Plotten van de graphs met jaarinformatie (deze kunnen mogelijk in de scriptie worden weergegeven)
yearFrame.plot(x=yearFrame.index.values, y='Zinnen')
yearFrame.plot(x=yearFrame.index.values, y='Paragrafen')
yearFrame.plot(x=yearFrame.index.values,y='Woorden')

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = 20, 10
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
yearFrame[["Paragrafen","Zinnen"]].plot()
plt.xlabel('Jaren')
plt.ylabel('Hoeveelheid')
plt.title("Aantal zinnen en paragrafen per jaar")
plt.savefig("Inhoudverdeling.png")

# %%
yearFrame[["Woorden"]].plot()
plt.xlabel('Jaren')
plt.ylabel('Aantal woorden')
plt.title("Aantal woorden per jaar")
plt.savefig("Woordverdeling.png")

# %%
woordenTotaal = yearFrame.sum(axis=0)
print woordenTotaal
for x in woordenTotaal:
    print x
# Out:
# Paragrafen        3887
# Zinnen           10415
# Woorden         224165
# Lettergrepen         0
# dtype: int64
# 3887
# 10415
# 224165
# 0

# %%
#Langste troonrede
longyear = ''
keep = 0
for x in yearData:
    if yearData[x][2] > keep:
        keep = yearData[x][2]
        longyear = x
print keep
print longyear
print yearData[longyear]
# Out:
# 3495
# 1993
# [39, 191, 3495, 0]

# %%
#Kortste troonrede
shortyear = ''
kept = 10000
for y in yearData:
    if yearData[y][2] < kept:
        kept = yearData[x][2]
        shortyear = y
print kept
print shortyear
print yearData[shortyear]
# Out:
# 1533
# 1880
# [16, 20, 343, 0]

# %%
alles = [3887,10415,224165]
gemiddeld = [x / 172 for x in alles]
langste = yearData[longyear][0:3]
kortste = yearData[shortyear][0:3]
statistieken = pd.DataFrame([alles,gemiddeld,langste,kortste],  columns =  ["Paragrafen", "Zinnen", "Woorden"])
print statistieken.to_latex()
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &  Paragrafen &  Zinnen &  Woorden \\
# \midrule
# 0 &        3887 &   10415 &   224165 \\
# 1 &          22 &      60 &     1303 \\
# 2 &          39 &     191 &     3495 \\
# 3 &          16 &      20 &      343 \\
# \bottomrule
# \end{tabular}

# %%
allYears = []
for y in range(1814,2015):
    allYears.append(str(y))
index = []
for x in yearFrame.index:
    index.append(x)
counter = 0
for w in allYears:
    if w not in index:
        counter += 1
        print w
# Out:
# 1881
# 1888
# 1889
# 1890
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1924
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1947
# 1977

# %%
missing = {}
missing["1888-1890"] = "Verhindering wegens ziekte"
missing["1905-1924"] = "Eerste wereldoorlog"
missing["1940-1947"] = "Tweede wereldoorlog"
missende = pd.DataFrame(missing.items(), columns=['Jaren',"reden"])
print missende.set_index("Jaren").sort_index().to_latex()
# Out:
# \begin{tabular}{ll}
# \toprule
# {} &                       reden \\
# Jaren     &                             \\
# \midrule
# 1888-1890 &  Verhindering wegens ziekte \\
# 1905-1924 &         Eerste wereldoorlog \\
# 1940-1947 &         Tweede wereldoorlog \\
# \bottomrule
# \end{tabular}

# %%
text_file = open("Output.dat", "w")
for item in netwerkDict:
    if netwerkDict[item] > 0.65:
        #if "ontwikkeling" in item or "regering" in item or "onderwijs" in item or "land" in item or "jaar" in item or "mens" in item or "beleid" in item:
        line = item[0] + " " + item[1]
        text_file.write(line)
        text_file.write("\n")
text_file.close()

# %%
for item in netwerkDict:
    if "wet" in item[0] or "wet" in item[1]:
        if netwerkDict[item] > 0.65:
            print item
# Out:
# ('edel', 'grondwet')
# ('wetboek', 'wetgeving')
# ('wetsontwerp', 'wijziging')
# ('voorbereiding', 'wet')
# ('grondwet', 'mogenden')
# ('grondwet', 'herziening')
# ('grondwet', 'regering')

# %%
netwerkDict = pickle.load( open( "netwerkFull.p", "rb" ) )

# %%
# Creeëren van de weighted graph vanuit de gevonden similarity scores
G = nx.Graph()
for item in netwerkDict:
    if netwerkDict[item] > 0.65:
        G.add_edge(str(item[0]),str(item[1]),weight=netwerkDict[item])

#G = nx.erdos_renyi_graph(100, 0.01)
    
pos=nx.spring_layout(G) # positions for all nodes

# nodes
nx.draw_networkx_nodes(G,pos,node_size=200)

# edges
nx.draw_networkx_edges(G,pos, width=4)

# labels
#nx.draw_networkx_labels(G,pos,font_size=10,font_family='sans-serif')

plt.axis('off')
plt.savefig("weighted_graph.png") # save as png
plt.figure(figsize=(1000,1000))
plt.show() # display

# %%
print G.nodes()
# Out:
# ['infrastructuur', 'werkloosheid', 'aanpak', 'democratie', 'investeer', 'gebied', 'investering', 'middeel', 'vertegenwoordiger', 'samenleving', 'organisatie', 'bijdraag', 'financiering', 'behandeling', 'mogelijkheid', 'provincie', 'onderwerp', 'economische', 'mogendheid', 'samenwerking', 'kracht', 'justitie', 'centraal', 'mens', 'markt', 'vrede', 'conferentie', 'omvang', 'zitting', 'baan', 'cultuur', 'moeilijkheid', 'begroting', 'maatregel', 'werkgever', 'natie', 'dag', 'duurzame', 'werknemer', 'onderwijs', 'groei', 'wetgeving', 'behoud', 'groep', 'gezin', 'gemeent', 'oplossing', 'bevordering', 'dienstverlening', 'advies', 'inzet', 'ingang', 'name', 'aansluiting', 'leven', 'begeleiding', 'bevordeer', 'inflatie', 'bestrijding', 'januari', 'gemeenschap', 'inkomen', 'herziening', 'jeugd', 'kennis', 'uitgaf', 'stabiliteit', 'bijdrage', 'handhaf', 'burger', 'bedraag', 'economie', 'kans', 'aanpassing', 'wetboek', 'maand', 'doel', 'voorbereiding', 'mate', 'noodzaak', 'armoede', 'onderneming', 'onzekerheid', 'europa', 'invoering', 'kader', 'maatschappij', 'beperking', 'besluit', 'hulp', 'bestuur', 'ontwikkel', 'wetsontwerp', 'ontwikkelingsland', 'programma', 'last', 'evenwicht', 'regering', 'rijk', 'koninkrijk', 'woning', 'noodzakelijk', 'mogenden', 'verenigde', 'betekenis', 'bedrijf', 'behoeve', 'activiteit', 'wijziging', 'antillen', 'perspectief', 'premie', 'verbetering', 'volk', 'unie', 'aanzien', 'ondernemer', 'kabinet', 'algemeen', 'criminaliteit', 'kind', 'versterking', 'grondwet', 'arbeid', 'basis', 'overheid', 'belang', 'regeling', 'zorg', 'prioriteit', 'hervorming', 'regel', 'bedrijfsleven', 'veiligheid', 'onderzoek', 'nodig', 'heden', 'aard', 'hooger', 'ontwerp', 'oog', 'leerkracht', 'nederland', 'doelstelling', 'wet', 'invloed', 'lidstaat', 'herstel', 'docent', 'landbouw', 'loon', 'beroepsonderwij', 'eis', 'edel', 'rijks', 'werkgelegenheid', 'politie', 'positie', 'werk', 'behoefte', 'initiatief', 'ontwikkeling', 'overleg', 'welvaart', 'staten-generaal', 'staten', 'indien', 'belasting', 'deel', 'woningbouw', 'integratie', 'partner', 'betrekking', 'recht', 'aantal', 'produktie', 'leraar', 'aandacht', 'gebruik', 'zoo', 'milieu', 'leed', 'structuur', 'nota', 'kunst', 'bescherming', 'kwaliteit', 'instelling', 'conflict', 'plaats', 'begin', 'vrijheid', 'koopkracht', 'verdrag', 'beleid', 'indonesi', 'beroep', 'hand', 'toestand', 'plan', 'inkomstenbelasting', 'bevolking', 'middelbaar', 'euro', 'land', 'handel', 'niveau', 'raad', 'overweging', 'geldmiddeel', 'gevolg', 'medewerking', 'afspraak', 'leerling', 'omstandigheid', 'inspanning', 'probleem', 'wereld']

# %%
# Vergroten van de graphs zodat ze duidelijker zijn
# %pylab inline
pylab.rcParams['figure.figsize'] = 20, 30
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
G = nx.Graph()
for item in netwerkDict:
    #if "regering" not in item and "onderwijs" not in item and "land" not in item and "unie" not in item and "samenleving" not in item and "nederland" not in item and "ontwikkeling" not in item and "mens" not in item:
    #if "ontwikkeling" in item or "regering" in item or "onderwijs" in item or "land" in item or "jaar" in item or "mens" in item or "beleid" in item:
    #if "samenwerking" in item:
        if netwerkDict[item] > 0.65:
            G.add_edge(str(item[0]),str(item[1]),weight=netwerkDict[item])
    
partition = community.best_partition(G)

#drawing
size = float(len(set(partition.values())))
pos = nx.spring_layout(G)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys()
                                if partition[nodes] == com]
    nx.draw_networkx_nodes(G, pos, list_nodes, node_size = 20,
                                node_color = str(count / size))


nx.draw_networkx_edges(G,pos, alpha=0.5)
nx.draw_networkx_labels(G,pos,font_size=14,font_family='sans-serif')
plt.xlim(-1.2,1.2)
plt.ylim(-1.2,1)
#plt.savefig("graph09.png")
plt.show()

# %%
#Het clusteren via de community module

#first compute the best partition
partition = community.best_partition(G)

#drawing
size = float(len(set(partition.values())))
pos = nx.spring_layout(G)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys()
                                if partition[nodes] == com]
    nx.draw_networkx_nodes(G, pos, list_nodes, node_size = 20,
                                node_color = str(count / size))


nx.draw_networkx_edges(G,pos, alpha=0.5)
nx.draw_networkx_labels(G,pos,font_size=15,font_family='sans-serif')
plt.xlim(-0.4,0.4)
plt.ylim(-0.4,0.4)
#plt.savefig("zoomedFinal.png")
plt.show()

# %%
# Onderwerpen met de bijbehorende termen
binnenlandsbeleid = ['infrastructuur', 'aanpak', 'investeer', 'gebied', 'investering', 'prijsbeleid', 'middeel', 'organisatie', 
                   'bijdraag', 'behoeft', 'behandeling', 'mogelijkheid', 'provincie', 'matiging', 'economische', 'evenwicht', 
                   'kracht', 'centraal', 'mens', 'markt', 'innovatie', 'keuze', 'onderzoek', 'baan', 'cultuur', 'grondslag', 
                   'bouw', 'moeilijkheid', 'begroting', 'maatregel', 'natie', 'duurzame', 'onderwijs', 'kind', 'groep', 'gemeent', 
                   'kwaliteit', 'bevordering', 'aansluiting', 'advies', 'ingang', 'name', 'dienstverlening', 'leven', 'begeleiding', 
                   'bevordeer', 'bestrijding', 'bestuur', 'programma', 'herziening', 'jeugd', 'kennis', 'bijdrage', 'handhaf', 
                   'burger', 'economie', 'loonvorming', 'kans', 'aanpassing', 'doel', 'kamer', 'mate', 'noodzaak', 'beroep', 
                   'europa', 'invoering', 'fundament', 'maatschappij', 'beperking', 'hulp', 'januari', 'hand', 'ontwikkelingsland', 
                   'gemeenschap', 'last', 'regering', 'koninkrijk', 'eis', 'noodzakelijk', 'koopkracht', 'betekenis', 'behoeve', 
                   'activiteit', 'antillen', 'perspectief', 'premie', 'gezin', 'inzet', 'ondernemer', 'belastingdruk', 'kabinet', 
                   'criminaliteit', 'grondwet', 'nederlander', 'arbeid', 'basis', 'overheid', 'regeling', 'prioriteit', 'hervorming', 
                   'regel', 'bedrijfsleven', 'omvang', 'nodig', 'heden', 'ontwerp', 'oog', 'bescherming', 'nederland', 'grens', 
                   'doelstelling', 'invloed', 'lidstaat', 'herstel', 'docent', 'landbouw', 'loon', 'inkomen', 'procent', 'plaats', 
                   'instelling', 'positie', 'initiatief', 'ontwikkeling', 'overleg', 'ordening', 'indien', 'integratie', 'deel', 
                   'belasting', 'partner', 'betrekking', 'recht', 'produktie', 'bedraag', 'gebruik', 'rechtsstaat', 'milieu', 
                   'politie', 'nota', 'kunst', 'oplossing', 'gezondheidszorg', 'onzekerheid', 'groei', 'plan', 'inkomstenbelasting', 
                   'bevolking', 'euro', 'land', 'handel', 'niveau', 'loonkost', 'raad', 'democratie', 'gevolg', 'medewerking', 
                   'afspraak', 'leerling', 'omstandigheid', 'inspanning', 'probleem', 'financiering']
onderwijs = ['jeugd', 'ontwikkeling', 'kennis', 'docent', 'middeel', 'economie', 'samenleving', 'kans', 'mogelijkheid', 
             'doel', 'regeling', 'onderzoek', 'kunst', 'cultuur', 'kwaliteit', 'hooger', 'ontwerp', 'nederland', 'onderwijs', 
             'beroepsonderwij', 'aansluiting', 'name', 'instelling', 'leraar', 'leerling', 'invoering', 'regering', 'probleem']
arbeidsbeleid = ['werkgever', 'welvaart', 'werknemer', 'werkgelegenheid', 'werkloosheid', 'werk','scholing','volk','vertegenwoordiger','loon',
                'inkomstenbelasting']
koloniaalbeleid = ['curaao', 'schuld', 'rijk', 'opzicht', 'nederlandsch-indi', 'geldmiddeel', 'toestand', 'verbetering', 'tekort', 
                   'rijks', 'uitgaf']
wetgeving = ['wetboek', 'wetsontwerp', 'wetgeving', 'wet','wijziging','regeling','voorbereiding']
ontwikkeling = ['ontwikkeling', 'gebied', 'economie', 'betrekking', 'handel', 'kracht', 'overheid', 'mens', 'mate', 'onderzoek', 
                'mogelijkheid', 'bedrijfsleven', 'maatregel', 'oog', 'nederland', 'onderwijs', 'groei', 'bevolking', 'landbouw', 
                'eis', 'land', 'herstel', 'name', 'regering', 'plaats', 'bevordeer', 'gevolg', 'inspanning', 'gemeenschap']
staatplanning = ['antillen', 'ontwikkeling', 'gebied', 'bijdrage', 'burger', 'deel', 'middeel', 'economie', 'kabinet', 
                     'integratie', 'bijdraag', 'kans', 'mogelijkheid', 'duurzame', 'economische', 'aantal', 'handel', 'aandacht', 
                     'kracht', 'belang', 'mens', 'hervorming', 'betrekking', 'bescherming', 'cultuur', 'kwaliteit', 'armoede', 
                     'maatregel', 'dag', 'europa', 'bedrijfsleven', 'nederland', 'beleid', 'kader', 'groei', 'behoud', 'hulp', 
                     'inspanning', 'bevolking', 'inkomen', 'land', 'herstel', 'regering', 'koninkrijk', 'bevordeer', 'gevolg', 
                     'betekenis', 'bedrijf', 'gemeenschap']
defensie = ['regering', 'justitie', 'unie', 'politie', 'veiligheid', 'uitbreiding']
buitenlandsbeleid = ['verdrag', 'stabiliteit', 'unie', 'veiligheid', 'toekomst', 'wereld', 'uitbreiding','vrede','vrijdheid','verenigde',
                    'staten','europa','handel','natie', 'samenwerking', 'koninkrijk', 'betekenis', 'organisatie', 'gemeenschap']
namen = ["binnenlandsbeleid","onderwijs","arbeidsbeleid","koloniaalbeleid","wetgeving","ontwikkeling","staatplanning","defensie","buitenlandsbeleid"]

# %%
print namen
testing = pd.DataFrame(namen)
print testing.to_latex()
# Out:
# ['binnenlandsbeleid', 'onderwijs', 'arbeidsbeleid', 'koloniaalbeleid', 'wetgeving', 'ontwikkeling', 'staatplanning', 'defensie', 'buitenlandsbeleid']
# \begin{tabular}{ll}
# \toprule
# {} &                  0 \\
# \midrule
# 0 &  binnenlandsbeleid \\
# 1 &          onderwijs \\
# 2 &      arbeidsbeleid \\
# 3 &    koloniaalbeleid \\
# 4 &          wetgeving \\
# 5 &       ontwikkeling \\
# 6 &      staatplanning \\
# 7 &           defensie \\
# 8 &  buitenlandsbeleid \\
# \bottomrule
# \end{tabular}

# %%
#top 5 van elk cluster bepalen:
dictcount = {}
for i in koloniaalbeleid:
    counter = 0.0
    for year in tekst:
        for p in tekst[year]:
            for x in p:
                try:
                    w = x.encode('utf-8')
                except:
                    w = x.decode('unicode_escape').encode('ascii','ignore')
                if w == i:
                    counter += 1
    dictcount[i] = counter

# %%
counter = 0
tablelist = []
for x in sorted(dictcount,reverse=True,key=dictcount.get):
    if counter < 20:
        #if counter%2!= 0:
        tablelist.append(x)
        counter += 1
print tablelist
transform = pd.DataFrame(tablelist)
print transform.to_latex()
# Out:
# ['verbetering', 'toestand', 'uitgaf', 'rijk', 'rijks', 'tekort', 'opzicht', 'geldmiddeel', 'schuld', 'curaao', 'nederlandsch-indi']
# \begin{tabular}{ll}
# \toprule
# {} &                  0 \\
# \midrule
# 0  &        verbetering \\
# 1  &           toestand \\
# 2  &             uitgaf \\
# 3  &               rijk \\
# 4  &              rijks \\
# 5  &             tekort \\
# 6  &            opzicht \\
# 7  &        geldmiddeel \\
# 8  &             schuld \\
# 9  &             curaao \\
# 10 &  nederlandsch-indi \\
# \bottomrule
# \end{tabular}

# %%
# Voor elk onderwerp per jaar de percentages berekenen dat het onderwerp voorkomt in dat jaar
yearlist = []
for year in sorted(tekst.keys()):
    thisyear = []
    c1 = 0.0
    c2 = 0.0
    c3 = 0.0
    c4 = 0.0
    c5 = 0.0
    c6 = 0.0
    c7 = 0.0
    c8 = 0.0
    c9 = 0.0
    part = 0.0
    total = 0.0
    for p in tekst[year]:
        for x in p:
            try:
                w = x.encode('utf-8')
            except:
                w = x.decode('unicode_escape').encode('ascii','ignore')
            if w in binnenlandsbeleid:
                c1 += 1
            if w in onderwijs:
                c2 += 1
            if w in arbeidsbeleid:
                c3 += 1
            if w in koloniaalbeleid:
                c4 += 1
            if w in wetgeving:
                c5 += 1
            if w in ontwikkeling:
                c6 += 1
            if w in staatplanning:
                c7 += 1
            if w in defensie:
                c8 += 1
            if w in buitenlandsbeleid:
                c9 += 1
    total = c1+c2+c3+c4+c5+c6+c7+c8+c9
    catlist = [c1,c2,c3,c4,c5,c6,c7,c8,c9]
    for cat in catlist:
        part = cat/total
        thisyear.append(part*100)
    yearlist.append(thisyear)

# %%
# transformeren van de lijsten zodat ze makkelijk geplot kunnen worden
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
list7 = []
list8 = []
list9 = []
for x in range(0,len(yearlist)):
    list1.append(np.cumsum(yearlist[x])[0])
    list2.append(np.cumsum(yearlist[x])[1])
    list3.append(np.cumsum(yearlist[x])[2])
    list4.append(np.cumsum(yearlist[x])[3])
    list5.append(np.cumsum(yearlist[x])[4])
    list6.append(np.cumsum(yearlist[x])[5])
    list7.append(np.cumsum(yearlist[x])[6])
    list8.append(np.cumsum(yearlist[x])[7])
    list9.append(np.cumsum(yearlist[x])[8])
allyears = [list1,list2,list3,list4,list5,list6,list7,list8,list9]

# %%
# Vergroten van de graphs zodat ze duidelijker zijn
# %pylab inline
pylab.rcParams['figure.figsize'] = 40, 30
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print len(yearlist)
# Out:
# 170

# %%
#Maken van de plot voor figuur 4
yearList = yearFrame.index.values
times = [x for x in xrange(0,len(yearList))]
ticks = yearList[0::10]

# red dashes, blue squares and green triangles
plt.xlabel('Jaren')
plt.ylabel('Percentage')
plt.title('percentuele onderwerp verdeling per jaar')
plt.ylim(0,100)
plt.xlim(0,117)
plt.xticks(rotation=70)
plt.xticks(np.arange(0, 173, 10.0),ticks)
counter = 0
colors = ["blue","red","green","black","orange","yellow","brown","purple","cyan"]
for cat in allyears:
    test = plt.plot(times,cat,colors[counter],label=namen[counter],linewidth=7)
    if counter == 0:
        plt.fill_between(times,0,allyears[0])
    else:
        plt.fill_between(times,allyears[counter-1],allyears[counter],facecolor=colors[counter])
    counter += 1
plt.legend(loc='lower left',fontsize=25,title="Onderwerpen",handlelength=5)
plt.rcParams.update({'font.size': 25})
plt.savefig("onderwerpverdeling.png")
plt.show()
